# %%
import numpy
import tensorflow as tf
import pandas
pandas.set_option('display.precision',10)
from tensorflow.keras import layers
##from tf.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

# %%
# load dataset
dataframe = pandas.read_csv("housing.csv", delim_whitespace=True, header=None)
dataset = dataframe.values
# split into input (X) and output (Y) variables
X = dataset[:,0:13]
Y = dataset[:,13]

# %%
# define base model
def baseline_model():
	# create model
	model = tf.keras.Sequential()
	model.add(layers.Dense(13, input_dim=13, kernel_initializer='normal', activation='relu'))
	model.add(layers.Dense(1, kernel_initializer='normal'))
	# Compile model
	model.compile(loss='mean_squared_error', optimizer='adam')
	return model

# %%
#fix random seed for reproducibility
seed = 7
numpy.random.seed(seed)
# evaluate model with standardized dataset
estimator = KerasRegressor(build_fn=baseline_model, epochs=100, batch_size=5, verbose=0)

# %%
kfold = KFold(n_splits=10, random_state=seed)
results = cross_val_score(estimator, X, Y, cv=kfold)
print("Results: %.2f (%.2f) MSE" % (results.mean(), results.std()))
# Out:
# Results: -35.40 (34.49) MSE

# %%
# evaluate model with standardized dataset
numpy.random.seed(seed)
estimators = []
estimators.append(('standardize', StandardScaler()))
estimators.append(('mlp', KerasRegressor(build_fn=baseline_model, epochs=50, batch_size=5, verbose=0)))
pipeline = Pipeline(estimators)
kfold = KFold(n_splits=10, random_state=seed)
results = cross_val_score(pipeline, X, Y, cv=kfold)
print("Standardized: %.2f (%.2f) MSE" % (results.mean(), results.std()))
# Out:
# Standardized: -27.60 (27.78) MSE

# %%
# define the model
def larger_model():
	# create model
	model = tf.keras.Sequential()
	model.add(Dense(13, input_dim=13, kernel_initializer='normal', activation='relu'))
	model.add(Dense(6, kernel_initializer='normal', activation='relu'))
	model.add(Dense(1, kernel_initializer='normal'))
	# Compile model
	model.compile(loss='mean_squared_error', optimizer='adam')
	return model

# %%
numpy.random.seed(seed)
estimators = []
estimators.append(('standardize', StandardScaler()))
estimators.append(('mlp', KerasRegressor(build_fn=larger_model, epochs=50, batch_size=5, verbose=0)))
pipeline = Pipeline(estimators)
kfold = KFold(n_splits=10, random_state=seed)
results = cross_val_score(pipeline, X, Y, cv=kfold)
print("Larger: %.2f (%.2f) MSE" % (results.mean(), results.std()))
# Out:
# Larger: -23.91 (28.06) MSE

# %%
# define wider model
def wider_model():
	# create model
	model = tf.keras.Sequential()
	model.add(Dense(20, input_dim=13, kernel_initializer='normal', activation='relu'))
	model.add(Dense(1, kernel_initializer='normal'))
	# Compile model
	model.compile(loss='mean_squared_error', optimizer='adam')
	return model

# %%
numpy.random.seed(seed)
estimators = []
estimators.append(('standardize', StandardScaler()))
estimators.append(('mlp', KerasRegressor(build_fn=wider_model, epochs=100, batch_size=5, verbose=0)))
pipeline = Pipeline(estimators)
kfold = KFold(n_splits=10, random_state=seed)
results = cross_val_score(pipeline, X, Y, cv=kfold)
print("Wider: %.2f (%.2f) MSE" % (results.mean(), results.std()))
# Out:
# Wider: -22.11 (24.78) MSE

# %%
#Progress2 trying to predict

# %%
from tensorflow.keras.models import Sequential
from sklearn.datasets import make_regression
from sklearn.preprocessing import MinMaxScaler

# %%
def final_model():
    # create model
    model = Sequential()
    model.add(Dense(20, input_dim=13, kernel_initializer='normal', activation='relu'))
    model.add(Dense(1, kernel_initializer='normal'))
    model.add(Dense(1, activation='linear'))
    # Compile model
    model.compile(loss='mean_squared_error', optimizer='adam')
    model.fit(X, Y, epochs=1000, verbose=0)
    return model

# %%
numpy.random.seed(seed)
estimators = []
estimators.append(('standardize', StandardScaler()))
estimators.append(('mlp', KerasRegressor(build_fn=final_model, epochs=100, batch_size=5, verbose=0)))
pipeline = Pipeline(estimators)
kfold = KFold(n_splits=10, random_state=seed)
results = cross_val_score(pipeline, X, Y, cv=kfold)
print("Final: %.2f (%.2f) MSE" % (results.mean(), results.std()))
# Out:
# Final: -18.82 (22.11) MSE

# %%
ynew = final_model().predict(X)
indexes = [0]*len(X)
for i in range(len(X)):
    print("Actual=%s, Predicted=%s" % (Y[i], ynew[i]))
    indexes[i] = i
# Out:
# Actual=24.0, Predicted=[32.60422]
# Actual=21.6, Predicted=[24.35049]
# Actual=34.7, Predicted=[33.24805]
# Actual=33.4, Predicted=[35.738712]
# Actual=36.2, Predicted=[32.69738]
# Actual=28.7, Predicted=[29.055672]
# Actual=22.9, Predicted=[21.961763]
# Actual=27.1, Predicted=[20.428429]
# Actual=16.5, Predicted=[17.87443]
# Actual=18.9, Predicted=[19.978859]
# Actual=15.0, Predicted=[20.812838]
# Actual=18.9, Predicted=[20.756674]
# Actual=21.7, Predicted=[23.007872]
# Actual=20.4, Predicted=[21.065403]
# Actual=18.2, Predicted=[19.643967]
# Actual=19.9, Predicted=[21.057682]
# Actual=23.1, Predicted=[22.604053]
# Actual=17.5, Predicted=[19.64176]
# Actual=20.2, Predicted=[17.62146]
# Actual=18.2, Predicted=[19.970089]
# Actual=13.6, Predicted=[16.932497]
# Actual=19.6, Predicted=[19.408392]
# Actual=15.2, Predicted=[19.737331]
# Actual=14.5, Predicted=[18.159342]
# Actual=15.6, Predicted=[18.880182]
# Actual=13.9, Predicted=[15.2701435]
# Actual=16.6, Predicted=[18.130842]
# Actual=14.8, Predicted=[16.504517]
# Actual=18.4, Predicted=[20.44795]
# Actual=21.0, Predicted=[21.189598]
# Actual=12.7, Predicted=[16.888548]
# Actual=14.5, Predicted=[18.380102]
# Actual=13.2, Predicted=[13.9254875]
# Actual=13.1, Predicted=[17.012232]
# Actual=13.5, Predicted=[14.216759]
# Actual=18.9, Predicted=[22.166355]
# Actual=20.0, Predicted=[21.578756]
# Actual=21.0, Predicted=[23.296541]
# Actual=24.7, Predicted=[24.17542]
# Actual=30.8, Predicted=[31.223017]
# Actual=34.9, Predicted=[38.67341]
# Actual=26.6, Predicted=[31.110895]
# Actual=25.3, Predicted=[27.019165]
# Actual=24.7, Predicted=[26.537422]
# Actual=21.2, Predicted=[23.57025]
# Actual=19.3, Predicted=[23.208559]
# Actual=20.0, Predicted=[23.45715]
# Actual=16.6, Predicted=[20.633417]
# Actual=14.4, Predicted=[17.906097]
# Actual=19.4, Predicted=[20.773193]
# Actual=19.7, Predicted=[22.961071]
# Actual=20.5, Predicted=[22.980913]
# Actual=25.0, Predicted=[30.023458]
# Actual=23.4, Predicted=[24.681313]
# Actual=18.9, Predicted=[19.13462]
# Actual=35.4, Predicted=[33.373005]
# Actual=24.7, Predicted=[24.681]
# Actual=31.6, Predicted=[37.40053]
# Actual=23.3, Predicted=[23.607315]
# Actual=19.6, Predicted=[22.371906]
# Actual=18.7, Predicted=[20.403866]
# Actual=16.0, Predicted=[19.022192]
# Actual=22.2, Predicted=[24.264914]
# Actual=25.0, Predicted=[24.700588]
# Actual=33.0, Predicted=[27.490053]
# Actual=23.5, Predicted=[28.896837]
# Actual=19.4, Predicted=[22.796722]
# Actual=22.0, Predicted=[22.83339]
# Actual=17.4, Predicted=[20.93715]
# Actual=20.9, Predicted=[22.155458]
# Actual=24.2, Predicted=[25.548958]
# Actual=21.7, Predicted=[23.187101]
# Actual=22.8, Predicted=[24.67224]
# Actual=23.4, Predicted=[24.776281]
# Actual=24.1, Predicted=[26.63801]
# Actual=21.4, Predicted=[22.213991]
# Actual=20.0, Predicted=[20.218102]
# Actual=20.8, Predicted=[21.969833]
# Actual=21.2, Predicted=[21.38132]
# Actual=20.3, Predicted=[21.884008]
# Actual=28.0, Predicted=[29.16279]
# Actual=23.9, Predicted=[25.648853]
# Actual=24.8, Predicted=[25.69302]
# Actual=22.9, Predicted=[23.473984]
# Actual=23.9, Predicted=[24.978334]
# Actual=26.6, Predicted=[28.704277]
# Actual=22.5, Predicted=[23.583733]
# Actual=22.2, Predicted=[25.2538]
# Actual=23.6, Predicted=[32.052177]
# Actual=28.7, Predicted=[33.185585]
# Actual=22.6, Predicted=[26.274942]
# Actual=22.0, Predicted=[26.67691]
# Actual=22.9, Predicted=[24.24096]
# Actual=25.0, Predicted=[25.223269]
# Actual=20.6, Predicted=[22.273758]
# Actual=28.4, Predicted=[26.41334]
# Actual=21.4, Predicted=[22.537252]
# Actual=38.7, Predicted=[41.06412]
# Actual=43.8, Predicted=[42.65722]
# Actual=33.2, Predicted=[34.059105]
# Actual=27.5, Predicted=[22.407738]
# Actual=26.5, Predicted=[23.554535]
# Actual=18.6, Predicted=[15.511115]
# Actual=19.3, Predicted=[20.061737]
# Actual=20.1, Predicted=[20.095406]
# Actual=19.5, Predicted=[18.799417]
# Actual=19.5, Predicted=[18.990402]
# Actual=20.4, Predicted=[20.159933]
# Actual=19.8, Predicted=[20.699432]
# Actual=19.4, Predicted=[20.006725]
# Actual=21.7, Predicted=[22.174522]
# Actual=22.8, Predicted=[22.497963]
# Actual=18.8, Predicted=[19.327686]
# Actual=18.7, Predicted=[19.67115]
# Actual=18.5, Predicted=[20.842623]
# Actual=18.3, Predicted=[17.92188]
# Actual=21.2, Predicted=[21.239567]
# Actual=19.2, Predicted=[20.238903]
# Actual=20.4, Predicted=[18.44798]
# Actual=19.3, Predicted=[20.199434]
# Actual=22.0, Predicted=[21.641314]
# Actual=20.3, Predicted=[20.835983]
# Actual=20.5, Predicted=[20.141188]
# Actual=17.3, Predicted=[19.155058]
# Actual=18.8, Predicted=[19.771166]
# Actual=21.4, Predicted=[20.809708]
# Actual=15.7, Predicted=[18.106329]
# Actual=16.2, Predicted=[16.972103]
# Actual=18.0, Predicted=[19.237461]
# Actual=14.3, Predicted=[16.76469]
# Actual=19.2, Predicted=[20.421295]
# Actual=19.6, Predicted=[19.57589]
# Actual=23.0, Predicted=[20.79874]
# Actual=18.4, Predicted=[17.064999]
# Actual=15.6, Predicted=[14.843664]
# Actual=18.1, Predicted=[18.690712]
# Actual=17.4, Predicted=[17.33631]
# Actual=17.1, Predicted=[19.233973]
# Actual=13.3, Predicted=[17.289234]
# Actual=17.8, Predicted=[18.353516]
# Actual=14.0, Predicted=[18.338034]
# Actual=14.4, Predicted=[14.169258]
# Actual=13.4, Predicted=[17.659023]
# Actual=15.6, Predicted=[16.985807]
# Actual=11.8, Predicted=[15.719152]
# Actual=13.8, Predicted=[14.744673]
# Actual=15.6, Predicted=[20.186583]
# Actual=14.6, Predicted=[15.806833]
# Actual=17.8, Predicted=[15.557568]
# Actual=15.4, Predicted=[16.625881]
# Actual=21.5, Predicted=[21.06602]
# Actual=19.6, Predicted=[19.567982]
# Actual=15.3, Predicted=[18.683064]
# Actual=19.4, Predicted=[18.434156]
# Actual=17.0, Predicted=[20.262424]
# Actual=15.6, Predicted=[17.89392]
# Actual=13.1, Predicted=[18.39176]
# Actual=41.3, Predicted=[38.451485]
# Actual=24.3, Predicted=[28.279015]
# Actual=23.3, Predicted=[28.45957]
# Actual=27.0, Predicted=[32.19085]
# Actual=50.0, Predicted=[49.287575]
# Actual=50.0, Predicted=[54.136967]
# Actual=50.0, Predicted=[52.78251]
# Actual=22.7, Predicted=[20.399553]
# Actual=25.0, Predicted=[23.967192]
# Actual=50.0, Predicted=[46.353195]
# Actual=23.8, Predicted=[18.210266]
# Actual=23.8, Predicted=[22.670141]
# Actual=22.3, Predicted=[22.579206]
# Actual=17.4, Predicted=[18.134993]
# Actual=19.1, Predicted=[20.46691]
# Actual=23.1, Predicted=[20.4359]
# Actual=23.6, Predicted=[26.888388]
# Actual=22.6, Predicted=[23.862797]
# Actual=29.4, Predicted=[34.864098]
# Actual=23.2, Predicted=[24.079014]
# Actual=24.6, Predicted=[29.6581]
# Actual=29.9, Predicted=[31.713417]
# Actual=37.2, Predicted=[37.030285]
# Actual=39.8, Predicted=[36.97815]
# Actual=36.2, Predicted=[28.29292]
# Actual=37.9, Predicted=[36.63497]
# Actual=32.5, Predicted=[32.694603]
# Actual=26.4, Predicted=[20.845793]
# Actual=29.6, Predicted=[23.552032]
# Actual=50.0, Predicted=[42.403976]
# Actual=32.0, Predicted=[32.04549]
# Actual=29.8, Predicted=[33.550957]
# Actual=34.9, Predicted=[36.09993]
# Actual=37.0, Predicted=[31.776478]
# Actual=30.5, Predicted=[31.883839]
# Actual=36.4, Predicted=[38.331398]
# Actual=31.1, Predicted=[32.333164]
# Actual=29.1, Predicted=[30.529293]
# Actual=50.0, Predicted=[49.104156]
# Actual=33.3, Predicted=[40.681583]
# Actual=30.3, Predicted=[28.140594]
# Actual=34.6, Predicted=[34.481903]
# Actual=34.9, Predicted=[31.674986]
# Actual=32.9, Predicted=[32.10962]
# Actual=24.1, Predicted=[27.194847]
# Actual=42.3, Predicted=[43.28957]
# Actual=48.5, Predicted=[49.74304]
# Actual=50.0, Predicted=[53.186703]
# Actual=22.6, Predicted=[24.286057]
# Actual=24.4, Predicted=[23.579224]
# Actual=22.5, Predicted=[20.366913]
# Actual=24.4, Predicted=[22.54144]
# Actual=20.0, Predicted=[18.296741]
# Actual=21.7, Predicted=[20.734749]
# Actual=19.3, Predicted=[19.172169]
# Actual=22.4, Predicted=[22.556]
# Actual=28.1, Predicted=[24.833685]
# Actual=23.7, Predicted=[21.59024]
# Actual=25.0, Predicted=[23.89168]
# Actual=23.3, Predicted=[23.4831]
# Actual=28.7, Predicted=[24.4825]
# Actual=21.5, Predicted=[21.536697]
# Actual=23.0, Predicted=[24.003727]
# Actual=26.7, Predicted=[28.987589]
# Actual=21.7, Predicted=[22.252851]
# Actual=27.5, Predicted=[28.28257]
# Actual=30.1, Predicted=[28.251774]
# Actual=44.8, Predicted=[44.399944]
# Actual=50.0, Predicted=[45.51539]
# Actual=37.6, Predicted=[44.409412]
# Actual=31.6, Predicted=[32.029076]
# Actual=46.7, Predicted=[43.32174]
# Actual=31.5, Predicted=[37.160122]
# Actual=24.3, Predicted=[21.834816]
# Actual=31.7, Predicted=[35.452076]
# Actual=41.7, Predicted=[47.001503]
# Actual=48.3, Predicted=[43.428703]
# Actual=29.0, Predicted=[27.324673]
# Actual=24.0, Predicted=[22.57636]
# Actual=25.1, Predicted=[26.644073]
# Actual=31.5, Predicted=[36.83714]
# Actual=23.7, Predicted=[27.13134]
# Actual=23.3, Predicted=[26.496239]
# Actual=22.0, Predicted=[25.10042]
# Actual=20.1, Predicted=[22.10283]
# Actual=22.2, Predicted=[22.660603]
# Actual=23.7, Predicted=[27.835981]
# Actual=17.6, Predicted=[17.75595]
# Actual=18.5, Predicted=[18.588139]
# Actual=24.3, Predicted=[22.390583]
# Actual=20.5, Predicted=[19.67428]
# Actual=24.5, Predicted=[22.14817]
# Actual=26.2, Predicted=[25.592451]
# Actual=24.4, Predicted=[25.662777]
# Actual=24.8, Predicted=[28.21628]
# Actual=29.6, Predicted=[29.838205]
# Actual=42.8, Predicted=[37.976624]
# Actual=21.9, Predicted=[22.484972]
# Actual=20.9, Predicted=[22.556278]
# Actual=44.0, Predicted=[42.7614]
# Actual=50.0, Predicted=[55.316994]
# Actual=36.0, Predicted=[40.537018]
# Actual=30.1, Predicted=[40.280228]
# Actual=33.8, Predicted=[34.401382]
# Actual=43.1, Predicted=[41.5454]
# Actual=48.8, Predicted=[50.38208]
# Actual=31.0, Predicted=[33.475025]
# Actual=36.5, Predicted=[38.08373]
# Actual=22.8, Predicted=[26.306147]
# Actual=30.7, Predicted=[27.950205]
# Actual=50.0, Predicted=[43.158623]
# Actual=43.5, Predicted=[47.55668]
# Actual=20.7, Predicted=[23.113249]
# Actual=21.1, Predicted=[23.113401]
# Actual=25.2, Predicted=[28.104105]
# Actual=24.4, Predicted=[27.633461]
# Actual=35.2, Predicted=[35.348537]
# Actual=32.4, Predicted=[37.808064]
# Actual=32.0, Predicted=[36.53941]
# Actual=33.2, Predicted=[33.593273]
# Actual=33.1, Predicted=[35.724266]
# Actual=29.1, Predicted=[28.685205]
# Actual=35.1, Predicted=[38.99215]
# Actual=45.4, Predicted=[43.63754]
# Actual=35.4, Predicted=[38.056633]
# Actual=46.0, Predicted=[45.409565]
# Actual=50.0, Predicted=[50.57322]
# Actual=32.2, Predicted=[29.535965]
# Actual=22.0, Predicted=[25.671133]
# Actual=20.1, Predicted=[21.59853]
# Actual=23.2, Predicted=[25.21186]
# Actual=22.3, Predicted=[24.917894]
# Actual=24.8, Predicted=[25.077118]
# Actual=28.5, Predicted=[35.20742]
# Actual=37.3, Predicted=[36.23183]
# Actual=27.9, Predicted=[30.422375]
# Actual=23.9, Predicted=[24.968761]
# Actual=21.7, Predicted=[23.15125]
# Actual=28.6, Predicted=[27.125294]
# Actual=27.1, Predicted=[24.655737]
# Actual=20.3, Predicted=[21.103882]
# Actual=22.5, Predicted=[26.776432]
# Actual=29.0, Predicted=[31.987644]
# Actual=24.8, Predicted=[28.919506]
# Actual=22.0, Predicted=[25.382051]
# Actual=26.4, Predicted=[25.987808]
# Actual=33.1, Predicted=[35.139668]
# Actual=36.1, Predicted=[34.55776]
# Actual=28.4, Predicted=[29.799997]
# Actual=33.4, Predicted=[36.41179]
# Actual=28.2, Predicted=[32.298313]
# Actual=22.8, Predicted=[29.297678]
# Actual=20.3, Predicted=[21.345758]
# Actual=16.1, Predicted=[18.55774]
# Actual=22.1, Predicted=[25.979134]
# Actual=19.4, Predicted=[20.775873]
# Actual=21.6, Predicted=[22.89549]
# Actual=23.8, Predicted=[22.835102]
# Actual=16.2, Predicted=[20.15512]
# Actual=17.8, Predicted=[20.074516]
# Actual=19.8, Predicted=[20.625845]
# Actual=23.1, Predicted=[22.941786]
# Actual=21.0, Predicted=[22.399902]
# Actual=23.8, Predicted=[24.901379]
# Actual=23.1, Predicted=[24.913237]
# Actual=20.4, Predicted=[22.804632]
# Actual=18.5, Predicted=[20.072287]
# Actual=25.0, Predicted=[26.011366]
# Actual=24.6, Predicted=[27.76166]
# Actual=23.0, Predicted=[25.22801]
# Actual=22.2, Predicted=[22.951809]
# Actual=19.3, Predicted=[22.095392]
# Actual=22.6, Predicted=[26.232197]
# Actual=19.8, Predicted=[21.8749]
# Actual=17.1, Predicted=[22.167736]
# Actual=19.4, Predicted=[22.505802]
# Actual=22.2, Predicted=[26.30097]
# Actual=20.7, Predicted=[25.252289]
# Actual=21.1, Predicted=[23.988213]
# Actual=19.5, Predicted=[23.015635]
# Actual=18.5, Predicted=[22.078386]
# Actual=20.6, Predicted=[24.289364]
# Actual=19.0, Predicted=[23.574224]
# Actual=18.7, Predicted=[22.756205]
# Actual=32.7, Predicted=[32.364143]
# Actual=16.5, Predicted=[22.015163]
# Actual=23.9, Predicted=[25.08913]
# Actual=31.2, Predicted=[30.264864]
# Actual=17.5, Predicted=[20.551268]
# Actual=17.2, Predicted=[19.203884]
# Actual=23.1, Predicted=[23.913488]
# Actual=24.5, Predicted=[27.565529]
# Actual=26.6, Predicted=[24.117352]
# Actual=22.9, Predicted=[22.386103]
# Actual=24.1, Predicted=[21.42355]
# Actual=18.6, Predicted=[21.003105]
# Actual=30.1, Predicted=[28.976107]
# Actual=18.2, Predicted=[19.968296]
# Actual=20.6, Predicted=[20.75756]
# Actual=17.8, Predicted=[17.391739]
# Actual=21.7, Predicted=[24.063356]
# Actual=22.7, Predicted=[25.027983]
# Actual=22.6, Predicted=[23.115135]
# Actual=25.0, Predicted=[33.3822]
# Actual=19.9, Predicted=[21.724909]
# Actual=20.8, Predicted=[27.76644]
# Actual=16.8, Predicted=[20.988213]
# Actual=21.9, Predicted=[44.58002]
# Actual=27.5, Predicted=[28.616755]
# Actual=21.9, Predicted=[20.271307]
# Actual=23.1, Predicted=[18.700106]
# Actual=50.0, Predicted=[43.90555]
# Actual=50.0, Predicted=[46.87623]
# Actual=50.0, Predicted=[51.43852]
# Actual=50.0, Predicted=[33.867725]
# Actual=50.0, Predicted=[33.15451]
# Actual=13.8, Predicted=[11.696207]
# Actual=13.8, Predicted=[7.1950827]
# Actual=15.0, Predicted=[22.492176]
# Actual=13.9, Predicted=[15.52952]
# Actual=13.3, Predicted=[18.152807]
# Actual=13.1, Predicted=[13.058517]
# Actual=10.2, Predicted=[13.970103]
# Actual=10.4, Predicted=[12.488533]
# Actual=10.9, Predicted=[15.6050415]
# Actual=11.3, Predicted=[14.281821]
# Actual=12.3, Predicted=[14.565868]
# Actual=8.8, Predicted=[10.995694]
# Actual=7.2, Predicted=[11.329435]
# Actual=10.5, Predicted=[7.743861]
# Actual=7.4, Predicted=[9.291477]
# Actual=10.2, Predicted=[10.089984]
# Actual=11.5, Predicted=[14.204776]
# Actual=15.1, Predicted=[15.573]
# Actual=23.2, Predicted=[17.266293]
# Actual=9.7, Predicted=[12.134975]
# Actual=13.8, Predicted=[19.058735]
# Actual=12.7, Predicted=[14.583602]
# Actual=13.1, Predicted=[17.326069]
# Actual=12.5, Predicted=[18.176424]
# Actual=8.5, Predicted=[15.360078]
# Actual=5.0, Predicted=[6.9066877]
# Actual=6.3, Predicted=[14.252177]
# Actual=5.6, Predicted=[11.089881]
# Actual=7.2, Predicted=[15.397469]
# Actual=12.1, Predicted=[16.64765]
# Actual=8.3, Predicted=[10.963641]
# Actual=8.5, Predicted=[8.813184]
# Actual=5.0, Predicted=[5.6777916]
# Actual=11.9, Predicted=[9.617796]
# Actual=27.9, Predicted=[26.471336]
# Actual=17.2, Predicted=[16.107325]
# Actual=27.5, Predicted=[16.69608]
# Actual=15.0, Predicted=[19.911043]
# Actual=17.2, Predicted=[15.411265]
# Actual=17.9, Predicted=[9.322288]
# Actual=16.3, Predicted=[13.95923]
# Actual=7.0, Predicted=[9.336394]
# Actual=7.2, Predicted=[10.513772]
# Actual=7.5, Predicted=[10.27738]
# Actual=10.4, Predicted=[10.737788]
# Actual=8.8, Predicted=[9.621797]
# Actual=8.4, Predicted=[9.642647]
# Actual=16.7, Predicted=[21.539228]
# Actual=14.2, Predicted=[19.153885]
# Actual=20.8, Predicted=[18.384655]
# Actual=13.4, Predicted=[10.590339]
# Actual=11.7, Predicted=[11.412926]
# Actual=8.3, Predicted=[10.659695]
# Actual=10.2, Predicted=[9.543374]
# Actual=10.9, Predicted=[11.892814]
# Actual=11.0, Predicted=[10.200417]
# Actual=9.5, Predicted=[11.465064]
# Actual=14.5, Predicted=[14.493642]
# Actual=14.1, Predicted=[15.096827]
# Actual=16.1, Predicted=[20.92819]
# Actual=14.3, Predicted=[16.20857]
# Actual=11.7, Predicted=[17.699358]
# Actual=13.4, Predicted=[12.081491]
# Actual=9.6, Predicted=[15.697615]
# Actual=8.7, Predicted=[10.333718]
# Actual=8.4, Predicted=[9.9257765]
# Actual=12.8, Predicted=[14.794375]
# Actual=10.5, Predicted=[11.698182]
# Actual=17.1, Predicted=[16.503881]
# Actual=18.4, Predicted=[17.828886]
# Actual=15.4, Predicted=[16.634516]
# Actual=10.8, Predicted=[14.9463215]
# Actual=11.8, Predicted=[11.472847]
# Actual=14.9, Predicted=[17.708805]
# Actual=12.6, Predicted=[16.429758]
# Actual=14.1, Predicted=[16.17934]
# Actual=13.0, Predicted=[17.488274]
# Actual=13.4, Predicted=[17.480408]
# Actual=15.2, Predicted=[19.042664]
# Actual=16.1, Predicted=[17.712973]
# Actual=17.8, Predicted=[20.45084]
# Actual=14.9, Predicted=[16.034725]
# Actual=14.1, Predicted=[14.608856]
# Actual=12.7, Predicted=[14.1734]
# Actual=13.5, Predicted=[13.390893]
# Actual=14.9, Predicted=[15.431846]
# Actual=20.0, Predicted=[19.519981]
# Actual=16.4, Predicted=[16.767166]
# Actual=17.7, Predicted=[21.555197]
# Actual=19.5, Predicted=[21.400255]
# Actual=20.2, Predicted=[27.425299]
# Actual=21.4, Predicted=[22.596575]
# Actual=19.9, Predicted=[20.408321]
# Actual=19.0, Predicted=[14.534674]
# Actual=19.1, Predicted=[17.361013]
# Actual=19.1, Predicted=[14.062344]
# Actual=20.1, Predicted=[17.785948]
# Actual=19.9, Predicted=[18.734179]
# Actual=19.6, Predicted=[22.204351]
# Actual=23.2, Predicted=[23.012264]
# Actual=29.8, Predicted=[28.02343]
# Actual=13.8, Predicted=[15.662471]
# Actual=13.3, Predicted=[16.921345]
# Actual=16.7, Predicted=[18.599007]
# Actual=12.0, Predicted=[13.033931]
# Actual=14.6, Predicted=[16.06479]
# Actual=21.4, Predicted=[19.495989]
# Actual=23.0, Predicted=[25.818151]
# Actual=23.7, Predicted=[30.981066]
# Actual=25.0, Predicted=[33.730534]
# Actual=21.8, Predicted=[26.574026]
# Actual=20.6, Predicted=[23.324509]
# Actual=21.2, Predicted=[27.222378]
# Actual=19.1, Predicted=[19.085602]
# Actual=20.6, Predicted=[24.985308]
# Actual=15.2, Predicted=[17.05256]
# Actual=7.0, Predicted=[13.69115]
# Actual=8.1, Predicted=[11.458685]
# Actual=13.6, Predicted=[19.388783]
# Actual=20.1, Predicted=[21.367441]
# Actual=21.8, Predicted=[21.32371]
# Actual=24.5, Predicted=[22.599373]
# Actual=23.1, Predicted=[22.29032]
# Actual=19.7, Predicted=[18.832088]
# Actual=18.3, Predicted=[20.341148]
# Actual=21.2, Predicted=[21.557848]
# Actual=17.5, Predicted=[19.628834]
# Actual=16.8, Predicted=[20.667936]
# Actual=22.4, Predicted=[23.198818]
# Actual=20.6, Predicted=[21.559612]
# Actual=23.9, Predicted=[26.849182]
# Actual=22.0, Predicted=[24.812101]
# Actual=11.9, Predicted=[20.989424]

# %%
#Visualization
import matplotlib.pyplot as plt
plt.plot(indexes,ynew,color='red')
plt.plot(indexes,Y,color='blue')
plt.ylabel('Price')
plt.show()

# %%
#Visualization
import matplotlib.pyplot as plt
plt.plot(indexes[0:50],ynew[0:50],color='red')
plt.plot(indexes[0:50],Y[0:50],color='blue')
plt.ylabel('Price')
plt.show()
